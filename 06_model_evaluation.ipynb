# %%
import pandas as pd
import numpy as np
import pickle
import os

# %%
from sklearn.metrics import roc_auc_score,accuracy_score

# %%
from scipy.special import cbrt
import re

# %%
os.chdir('../pickles')

# %%
numerical = pickle.load(open('numerical.pickle','rb'))
categorical = pickle.load(open('categorical.pickle','rb'))
conversion_dict = pickle.load(open('conversion_dict.pickle','rb'))
imputation_cols = pickle.load(open('imputation_cols.pickle','rb'))
model_columns = pickle.load(open('model_columns','rb'))
lr_model_columns = pickle.load(open('lr_model_columns.pickle','rb'))
order = pickle.load(open('order.pickle','rb'))
scale = pickle.load(open('scale.pickle','rb'))
pca = pickle.load(open('pca.pickle','rb'))

# %%
os.chdir('../Input_Data')

# %%
df_val = pd.read_csv('validation.csv',header=0)

# %%
rename_dict = {col : col.replace('%','pct_') for col in df_val.columns if '%' in col}

# %%
df_val.rename(rename_dict,axis=1,inplace=True)

# %%
rename_dict={}
for col in order.keys():
    df_val[col]=df_val[col]/10**order[col]
    rename_dict[col] = col+"_order{}".format(order[col])

# %%
df_val.rename(rename_dict,axis=1,inplace=True)

# %%
for col in categorical:
    if len(conversion_dict[col])==1:
        category = conversion_dict[col][0]
        df_val[col+'_dum_'+str(category)] = 0
        df_val.loc[df_val[col]==category,col+'_dum_'+str(category)]=1
    else:
        total_categories = len(conversion_dict[col])
        dummies = len(str(int(bin(total_categories)[2:],10)))
        bin_conv=[]
        for i in range(total_categories):
            bin_conv.append(conversion_dict[col][i][1])
        for j in range(dummies):
            df_val[col+'_dum_'+str(j)]=0
            for i,cat in enumerate([conv[0] for conv in conversion_dict[col]]):
                df_val.loc[df_val[col]==cat,col+'_dum_'+str(j)]=bin_conv[i]%10
                bin_conv[i]=bin_conv[i]//10
    df_val.drop(col,axis=1,inplace=True)
    print(col+' done')
# Out:
# Sector done

# %%
os.chdir('../Statistics/')

# %%
edd_df = pd.read_excel('report.xlsx',sheet_name='edd_v01',header=0)

# %%
transform_dict = {'log':lambda x: np.log(x),'sqr':lambda x: x**2,'sqrt':lambda x: np.sqrt(x),'exp':lambda x:np.exp(x),
                 'cube':lambda x: x**3,'cuberoot': lambda x: cbrt(x)}

# %%
for col in list(edd_df['Var']):
    applied = edd_df.loc[edd_df['Var']==col,'conversions'].values[0]
    if applied != '' and applied != 'categorical':
        try:
            for t in applied.split(','):
                df_val[col+'_'+t] = df_val[col].apply(transform_dict[t])
        except:
            pass

# %%
os.chdir('../Imputation_models')

# %%
for col in [x for x in numerical if x!='lift_ind']:
    model = pickle.load(open(col+'_impute.pickle','rb'))
    if df_val[col].isnull().any():
        indices = df_val.loc[df_val[col].isnull()].index.tolist()
        df_val.loc[indices,col]=np.array(model.predict(np.array(df_val.loc[indices,imputation_cols])))
        del indices
    del model
    print(col+' imputed')
# Out:
# Prev_Close_order5 imputed
# High_1d_order5 imputed
# Low_1d_order5 imputed
# Last_1d_order5 imputed
# VWAP_1d_order5 imputed
# Volume_1d_order9 imputed
# Turnover_1d_order11 imputed
# Trades_1d_order7 imputed
# Deliverable_Volume_1d_order9 imputed
# pct_Deliverble_1d imputed
# Open_nifty_1d_order5 imputed
# High_nifty_1d_order5 imputed
# Low_nifty_1d_order5 imputed
# Close_nifty_1d_order5 imputed
# Volume_nifty_1d_order9 imputed
# Turnover_nifty_1d_order11 imputed
# Open_auto_1d_order5 imputed
# High_auto_1d_order5 imputed
# Low_auto_1d_order5 imputed
# Close_auto_1d_order5 imputed
# Open_bank_1d_order5 imputed
# High_bank_1d_order5 imputed
# Low_bank_1d_order5 imputed
# Close_bank_1d_order5 imputed
# Open_fmcg_1d_order5 imputed
# High_fmcg_1d_order5 imputed
# Low_fmcg_1d_order5 imputed
# Close_fmcg_1d_order5 imputed
# Open_it_1d_order5 imputed
# High_it_1d_order5 imputed
# Low_it_1d_order5 imputed
# Close_it_1d_order5 imputed
# Open_media_1d_order4 imputed
# High_media_1d_order4 imputed
# Low_media_1d_order4 imputed
# Close_media_1d_order4 imputed
# Open_metal_1d_order4 imputed
# High_metal_1d_order4 imputed
# Low_metal_1d_order4 imputed
# Close_metal_1d_order4 imputed
# Open_pharma_1d_order5 imputed
# High_pharma_1d_order5 imputed
# Low_pharma_1d_order5 imputed
# Close_pharma_1d_order5 imputed
# Open_realty_1d_order3 imputed
# High_realty_1d_order3 imputed
# Low_realty_1d_order3 imputed
# Close_realty_1d_order3 imputed
# Open_psu_1d_order4 imputed
# High_psu_1d_order4 imputed
# Low_psu_1d_order4 imputed
# Close_psu_1d_order4 imputed
# Open_500_1d_order5 imputed
# High_500_1d_order5 imputed
# Low_500_1d_order4 imputed
# Close_500_1d_order4 imputed
# return_1d_nifty imputed
# return_2d_nifty imputed
# return_3d_nifty imputed
# return_4d_nifty imputed
# return_5d_nifty imputed
# Voltality_nifty imputed
# return_1d_auto imputed
# return_2d_auto imputed
# return_3d_auto imputed
# return_4d_auto imputed
# return_5d_auto imputed
# Voltality_auto imputed
# return_1d_bank imputed
# return_2d_bank imputed
# return_3d_bank imputed
# return_4d_bank imputed
# return_5d_bank imputed
# Voltality_bank imputed
# return_1d_fmcg imputed
# return_2d_fmcg imputed
# return_3d_fmcg imputed
# return_4d_fmcg imputed
# return_5d_fmcg imputed
# Voltality_fmcg imputed
# return_1d_it imputed
# return_2d_it imputed
# return_3d_it imputed
# return_4d_it imputed
# return_5d_it imputed
# Voltality_it imputed
# return_1d_media imputed
# return_2d_media imputed
# return_3d_media imputed
# return_4d_media imputed
# return_5d_media imputed
# Voltality_media imputed
# return_1d_metal imputed
# return_2d_metal imputed
# return_3d_metal imputed
# return_4d_metal imputed
# return_5d_metal imputed
# Voltality_metal imputed
# return_1d_pharma imputed
# return_2d_pharma imputed
# return_3d_pharma imputed
# return_4d_pharma imputed
# return_5d_pharma imputed
# Voltality_pharma imputed
# return_1d_realty imputed
# return_2d_realty imputed
# return_3d_realty imputed
# return_4d_realty imputed
# return_5d_realty imputed
# Voltality_realty imputed
# return_1d_psu imputed
# return_2d_psu imputed
# return_3d_psu imputed
# return_4d_psu imputed
# return_5d_psu imputed
# Voltality_psu imputed
# return_1d_500 imputed
# return_2d_500 imputed
# return_3d_500 imputed
# return_4d_500 imputed
# return_5d_500 imputed
# Voltality_500 imputed
# return_1d imputed
# return_2d imputed
# return_3d imputed
# return_4d imputed
# return_5d imputed
# Voltality imputed
# Open_1d_order5 imputed
# Volume_1d_order9_log imputed
# Turnover_1d_order11_log imputed
# Trades_1d_order7_log imputed
# Deliverable_Volume_1d_order9_log imputed
# pct_Deliverble_1d_sqr imputed
# pct_Deliverble_1d_cube imputed
# pct_Deliverble_1d_exp imputed
# Open_nifty_1d_order5_log imputed
# High_nifty_1d_order5_log imputed
# Low_nifty_1d_order5_log imputed
# Close_nifty_1d_order5_log imputed
# Open_auto_1d_order5_sqr imputed
# High_auto_1d_order5_sqr imputed
# Low_auto_1d_order5_sqr imputed
# Close_auto_1d_order5_sqr imputed
# Open_bank_1d_order5_log imputed
# High_bank_1d_order5_log imputed
# Low_bank_1d_order5_log imputed
# Close_bank_1d_order5_log imputed
# Open_fmcg_1d_order5_log imputed
# High_fmcg_1d_order5_log imputed
# Low_fmcg_1d_order5_log imputed
# Close_fmcg_1d_order5_log imputed
# Open_media_1d_order4_log imputed
# High_media_1d_order4_log imputed
# Low_media_1d_order4_log imputed
# Close_media_1d_order4_log imputed
# Open_pharma_1d_order5_sqr imputed
# Open_pharma_1d_order5_cube imputed
# Open_pharma_1d_order5_exp imputed
# High_pharma_1d_order5_sqr imputed
# High_pharma_1d_order5_cube imputed
# High_pharma_1d_order5_exp imputed
# Low_pharma_1d_order5_sqr imputed
# Low_pharma_1d_order5_cube imputed
# Low_pharma_1d_order5_exp imputed
# Close_pharma_1d_order5_sqr imputed
# Close_pharma_1d_order5_cube imputed
# Close_pharma_1d_order5_exp imputed
# Low_psu_1d_order4_sqr imputed
# Open_500_1d_order5_log imputed
# High_500_1d_order5_log imputed
# Low_500_1d_order4_log imputed
# Close_500_1d_order4_log imputed
# return_1d_nifty_sqr imputed
# return_1d_nifty_cube imputed
# return_2d_nifty_sqr imputed
# return_2d_nifty_cube imputed
# return_3d_nifty_cube imputed
# return_4d_nifty_sqr imputed
# return_5d_nifty_sqr imputed
# Voltality_nifty_log imputed
# Voltality_auto_log imputed
# Voltality_bank_log imputed
# return_1d_fmcg_sqr imputed
# return_1d_fmcg_cube imputed
# return_2d_fmcg_sqr imputed
# return_2d_fmcg_cube imputed
# return_4d_fmcg_sqr imputed
# return_4d_fmcg_cube imputed
# return_5d_fmcg_sqr imputed
# Voltality_fmcg_log imputed
# return_2d_it_sqr imputed
# return_2d_it_cube imputed
# return_3d_it_sqr imputed
# return_3d_it_cube imputed
# return_4d_it_cube imputed
# Voltality_media_log imputed
# Voltality_metal_log imputed
# return_1d_realty_sqr imputed
# return_1d_realty_cube imputed
# return_2d_realty_sqr imputed
# return_2d_realty_cube imputed
# return_3d_realty_cube imputed
# Voltality_psu_log imputed
# return_1d_500_sqr imputed
# return_1d_500_cube imputed
# return_2d_500_sqr imputed
# return_2d_500_cube imputed
# return_3d_500_sqr imputed
# return_3d_500_cube imputed
# Voltality_500_log imputed

# %%
x_val,y_val = np.array(df_val[lr_model_columns]),np.array(df_val['lift_ind'])
x,y = np.array(df_val[model_columns]),np.array(df_val['lift_ind'])
x_pca,y_pca = pca.transform(scale.transform(np.array(df_val[model_columns]))),np.array(df_val['lift_ind'])

# %%
os.chdir('../Models')

# %%
models = {'LR':pickle.load(open('LR.pickle','rb')),
                      'RF':pickle.load(open('RF.pickle','rb')),
                    'GBM':pickle.load(open('GBM.pickle','rb')),
         'RF_full':pickle.load(open('RF_full.pickle','rb')),
         'GBM_full':pickle.load(open('GBM_full.pickle','rb')),
          'RF_pca' : pickle.load(open('RF_pca.pickle','rb')),
          'GBM_pca' : pickle.load(open('GBM_pca.pickle','rb'))
         }
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
df_val['RF_Prediction'] = models['RF'].predict_proba(x_val)[:,1]

# %%
df_val['GBM_Prediction'] = models['GBM'].predict_proba(x_val)[:,1]

# %%
df_val['LR_Prediction'] = models['LR'].predict_proba(df_val[lr_model_columns])[:,1]

# %%
df_val['RF_full_prediction'] = models['RF_full'].predict_proba(df_val[model_columns])[:,1]

# %%
df_val['GBM_full_prediction'] = models['GBM_full'].predict_proba(df_val[model_columns])[:,1]

# %%
df_val['RF_pca_prediction'] = models['RF_pca'].predict_proba(x_pca)[:,1]

# %%
df_val['GBM_pca_prediction'] = models['GBM_pca'].predict_proba(x_pca)[:,1]

# %%
scores = [roc_auc_score(df_val['lift_ind'],df_val['LR_Prediction']),roc_auc_score(df_val['lift_ind'],df_val['RF_Prediction']),roc_auc_score(df_val['lift_ind'],df_val['GBM_Prediction']),
         roc_auc_score(df_val['lift_ind'],df_val['RF_full_prediction']),roc_auc_score(df_val['lift_ind'],df_val['GBM_full_prediction']),
         roc_auc_score(df_val['lift_ind'],df_val['RF_pca_prediction']),roc_auc_score(df_val['lift_ind'],df_val['GBM_pca_prediction'])]

# %%
df_scores = pd.DataFrame(list(zip(['LR','RF','GBM','RF_full','GBM_full','RF_pca','GBM_pca'],scores)),columns=['models','roc_auc_score'])

# %%
df_scores
# Out:
#      models  roc_auc_score
# 0        LR       0.481843
# 1        RF       0.520416
# 2       GBM       0.524365
# 3   RF_full       0.544155
# 4  GBM_full       0.539097
# 5    RF_pca       0.507370
# 6   GBM_pca       0.484264

# %%
df_val['Ensembled_Prob'] = (.48*df_val['LR_Prediction']+.52*df_val['RF_Prediction']+.52*df_val['GBM_Prediction']+
                           .54*df_val['RF_full_prediction']+.54*df_val['GBM_full_prediction']
                           +.51*df_val['RF_pca_prediction']+.48*df_val['GBM_pca_prediction'])/(1.52+1.08+.99)

# %%
roc_auc_score(df_val['lift_ind'],df_val['Ensembled_Prob'])
# Out:
# 0.526332128263197

# %%
from openpyxl import load_workbook,Workbook

# %%
os.chdir('../Statistics/')

# %%
rf_importance = pd.DataFrame(list(zip(lr_model_columns,list(models['RF'].feature_importances_))),columns=['Var','Importance'])
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

rf_importance.to_excel(writer, "rf_feature_importance", index=False)

writer.save()

# %%
gbm_importance = pd.DataFrame(list(zip(lr_model_columns,list(models['GBM'].feature_importances_))),columns=['Var','Importance'])
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

gbm_importance.to_excel(writer, "gbm_feature_importance", index=False)

writer.save()

# %%
linear_importance = pd.DataFrame(list(zip([1]+list(lr_model_columns),[models['LR'].intercept_[0]]+list(models['LR'].coef_[0]))),columns=['Var','coeff'])
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

linear_importance.to_excel(writer, "linear_model_coef", index=False)

writer.save()

# %%
rf_importance = pd.DataFrame(list(zip(model_columns,list(models['RF_full'].feature_importances_))),columns=['Var','Importance'])
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

rf_importance.to_excel(writer, "rf_full_feature_importance", index=False)

writer.save()

# %%
gbm_importance = pd.DataFrame(list(zip(model_columns,list(models['GBM_full'].feature_importances_))),columns=['Var','Importance'])
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

gbm_importance.to_excel(writer, "gbm_full_feature_importance", index=False)

writer.save()

# %%
df_val['ensembled_prob2'] = (df_val['RF_full_prediction']+df_val['GBM_full_prediction'])/2

# %%
roc_auc_score(df_val['lift_ind'],df_val['ensembled_prob2'])
# Out:
# 0.5413460665498274

# %%
df_scores = df_scores.append(pd.DataFrame([['ensembled_all',0.526332128263197],
                                          ['ensembled_full',0.5413460665498274]],columns=df_scores.columns),ignore_index=True)

# %%
df_scores
# Out:
#            models  roc_auc_score
# 0              LR       0.481843
# 1              RF       0.520416
# 2             GBM       0.524365
# 3         RF_full       0.544155
# 4        GBM_full       0.539097
# 5          RF_pca       0.507370
# 6         GBM_pca       0.484264
# 7   ensembled_all       0.526332
# 8  ensembled_full       0.541346

# %%
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

df_scores.to_excel(writer, "model_scores", index=False)

writer.save()

# %%
def model_advanced_statistics(model_name,x_val,y_val):
    y_prob = models[model_name].predict_proba(x_val)[:,1]
    sorted_probs = sorted(list(zip(y_val,y_prob)),key = lambda x: x[1] , reverse = True)
    obs = len(list(y_val))//100
    base_df = pd.DataFrame(sorted_probs,columns=['label','prob'])
    pos,neg = sum(list(y_val)),len(list(y_val))-sum(list(y_val))
    base_df['Bucket'] = base_df.index//obs
    bucket_list = base_df.groupby(by='Bucket',axis=0).agg({'label' : ['count','sum'],'prob' : ['max','min','mean']})
    bucket_list.columns = bucket_list.columns.droplevel()
    bucket_list.columns = ['observations','true_positives','prob_max','prob_min','prob_mean']
    bucket_list['cum_observations'] = bucket_list['observations'].cumsum()
    bucket_list['cum_true_pos'] = bucket_list['true_positives'].cumsum()
    bucket_list['coverage'] = bucket_list['cum_true_pos']/list(bucket_list['cum_true_pos'])[-1]
    bucket_list['cum_true_pct'] = bucket_list['cum_true_pos']/bucket_list['cum_observations']
    return bucket_list

# %%
RF_Stats = model_advanced_statistics('RF',x_val,y_val)
GBM_Stats = model_advanced_statistics('GBM',x_val,y_val)
LR_Stats = model_advanced_statistics('LR',x_val,y_val)
RF_full_stats = model_advanced_statistics('RF_full',x,y)
GBM_full_stats = model_advanced_statistics('GBM_full',x,y)
RF_pca_stats = model_advanced_statistics('RF_pca',x_pca,y_pca)
GBM_pca_stats = model_advanced_statistics('GBM_pca',x_pca,y_pca)

# %%
for stats,name in [(RF_Stats,'RF'),(GBM_Stats,'GBM'),(LR_Stats,'LR'),(RF_full_stats,'RF_full'),
                  (GBM_full_stats,'GBM_full'),(RF_pca_stats,'RF_pca'),(GBM_pca_stats,'GBM_pca')]:
    book = load_workbook('report.xlsx')
    writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
    writer.book = book
    writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

    stats.to_excel(writer, name+'_stats')

    writer.save()

# %%
def model_stats_ensemble(y_prob,y_val):
    y_prob = y_prob
    sorted_probs = sorted(list(zip(y_val,y_prob)),key = lambda x: x[1] , reverse = True)
    obs = len(list(y_val))//100
    base_df = pd.DataFrame(sorted_probs,columns=['label','prob'])
    pos,neg = sum(list(y_val)),len(list(y_val))-sum(list(y_val))
    base_df['Bucket'] = base_df.index//obs
    bucket_list = base_df.groupby(by='Bucket',axis=0).agg({'label' : ['count','sum'],'prob' : ['max','min','mean']})
    bucket_list.columns = bucket_list.columns.droplevel()
    bucket_list.columns = ['observations','true_positives','prob_max','prob_min','prob_mean']
    bucket_list['cum_observations'] = bucket_list['observations'].cumsum()
    bucket_list['cum_true_pos'] = bucket_list['true_positives'].cumsum()
    bucket_list['coverage'] = bucket_list['cum_true_pos']/list(bucket_list['cum_true_pos'])[-1]
    bucket_list['cum_true_pct'] = bucket_list['cum_true_pos']/bucket_list['cum_observations']
    return bucket_list

# %%
ensembled_all_stats = model_stats_ensemble(df_val['Ensembled_Prob'],df_val['lift_ind'])
ensembled_full_stats = model_stats_ensemble(df_val['ensembled_prob2'],df_val['lift_ind'])

# %%
ensembled_full_stats
# Out:
#         observations  true_positives  prob_max  prob_min  prob_mean  \
# Bucket
# 0                 31              19  0.542088  0.534185   0.537300
# 1                 31              19  0.533875  0.518592   0.526375
# 2                 31              19  0.517997  0.511987   0.514718
# 3                 31              22  0.511928  0.510453   0.511266
# 4                 31              23  0.510436  0.508799   0.509620
# 5                 31              16  0.508729  0.506797   0.507731
# 6                 31              15  0.506788  0.505603   0.506139
# 7                 31              20  0.505590  0.504367   0.504857
# 8                 31              12  0.504347  0.503150   0.503693
# 9                 31              14  0.503103  0.502074   0.502488
# 10                31              16  0.501939  0.501085   0.501595
# 11                31              16  0.501027  0.499968   0.500532
# 12                31              12  0.499955  0.499094   0.499511
# 13                31              14  0.499042  0.498097   0.498491
# 14                31              12  0.498091  0.497303   0.497802
# 15                31              11  0.497302  0.496643   0.497011
# 16                31              17  0.496569  0.495849   0.496166
# 17                31              14  0.495843  0.495335   0.495564
# 18                31              16  0.495322  0.494823   0.495053
# 19                31              16  0.494786  0.494228   0.494525
# 20                31              10  0.494179  0.493587   0.493831
# 21                31              11  0.493572  0.492706   0.493203
# 22                31              19  0.492687  0.491879   0.492263
# 23                31              14  0.491869  0.491229   0.491586
# 24                31              16  0.491135  0.490347   0.490752
# 25                31              14  0.490340  0.489859   0.490081
# 26                31              19  0.489858  0.489124   0.489473
# 27                31              16  0.489066  0.488574   0.488791
# 28                31              13  0.488564  0.488004   0.488208
# 29                31              20  0.488001  0.487415   0.487659
# ...              ...             ...       ...       ...        ...
# 70                31              12  0.459234  0.458300   0.458740
# 71                31              13  0.458266  0.457656   0.457891
# 72                31              13  0.457656  0.456718   0.457240
# 73                31              14  0.456689  0.455902   0.456305
# 74                31               9  0.455853  0.455081   0.455513
# 75                31              16  0.455000  0.453952   0.454447
# 76                31              15  0.453916  0.452698   0.453247
# 77                31              15  0.452691  0.451789   0.452345
# 78                31              13  0.451746  0.449962   0.450864
# 79                31               8  0.449916  0.449192   0.449583
# 80                31               6  0.449184  0.448127   0.448768
# 81                31              13  0.448118  0.447134   0.447590
# 82                31               9  0.447124  0.446162   0.446635
# 83                31              12  0.446114  0.445238   0.445701
# 84                31              16  0.445214  0.444083   0.444575
# 85                31              10  0.444078  0.442816   0.443377
# 86                31              12  0.442740  0.441495   0.442252
# 87                31              11  0.441487  0.440121   0.440735
# 88                31              12  0.440018  0.438869   0.439409
# 89                31              17  0.438798  0.436966   0.437695
# 90                31              16  0.436745  0.432642   0.434744
# 91                31              15  0.432612  0.429193   0.430252
# 92                31              21  0.429058  0.426960   0.428088
# 93                31              16  0.426944  0.423463   0.425148
# 94                31              15  0.423439  0.420436   0.422180
# 95                31              16  0.420410  0.417460   0.418995
# 96                31              10  0.417423  0.414042   0.415466
# 97                31              11  0.413944  0.411036   0.412398
# 98                31              19  0.411034  0.405436   0.408360
# 99                31              18  0.404590  0.394455   0.400105
#
#         cum_observations  cum_true_pos  coverage  cum_true_pct
# Bucket
# 0                     31            19  0.013204      0.612903
# 1                     62            38  0.026407      0.612903
# 2                     93            57  0.039611      0.612903
# 3                    124            79  0.054899      0.637097
# 4                    155           102  0.070883      0.658065
# 5                    186           118  0.082001      0.634409
# 6                    217           133  0.092425      0.612903
# 7                    248           153  0.106324      0.616935
# 8                    279           165  0.114663      0.591398
# 9                    310           179  0.124392      0.577419
# 10                   341           195  0.135511      0.571848
# 11                   372           211  0.146630      0.567204
# 12                   403           223  0.154969      0.553350
# 13                   434           237  0.164698      0.546083
# 14                   465           249  0.173037      0.535484
# 15                   496           260  0.180681      0.524194
# 16                   527           277  0.192495      0.525617
# 17                   558           291  0.202224      0.521505
# 18                   589           307  0.213343      0.521222
# 19                   620           323  0.224461      0.520968
# 20                   651           333  0.231411      0.511521
# 21                   682           344  0.239055      0.504399
# 22                   713           363  0.252259      0.509116
# 23                   744           377  0.261987      0.506720
# 24                   775           393  0.273106      0.507097
# 25                   806           407  0.282835      0.504963
# 26                   837           426  0.296039      0.508961
# 27                   868           442  0.307158      0.509217
# 28                   899           455  0.316192      0.506118
# 29                   930           475  0.330090      0.510753
# ...                  ...           ...       ...           ...
# 70                  2201          1048  0.728284      0.476147
# 71                  2232          1061  0.737318      0.475358
# 72                  2263          1074  0.746352      0.474591
# 73                  2294          1088  0.756081      0.474281
# 74                  2325          1097  0.762335      0.471828
# 75                  2356          1113  0.773454      0.472411
# 76                  2387          1128  0.783878      0.472560
# 77                  2418          1143  0.794302      0.472705
# 78                  2449          1156  0.803336      0.472029
# 79                  2480          1164  0.808895      0.469355
# 80                  2511          1170  0.813065      0.465950
# 81                  2542          1183  0.822099      0.465382
# 82                  2573          1192  0.828353      0.463272
# 83                  2604          1204  0.836692      0.462366
# 84                  2635          1220  0.847811      0.462998
# 85                  2666          1230  0.854760      0.461365
# 86                  2697          1242  0.863099      0.460512
# 87                  2728          1253  0.870744      0.459311
# 88                  2759          1265  0.879083      0.458499
# 89                  2790          1282  0.890896      0.459498
# 90                  2821          1298  0.902015      0.460121
# 91                  2852          1313  0.912439      0.460379
# 92                  2883          1334  0.927033      0.462712
# 93                  2914          1350  0.938151      0.463281
# 94                  2945          1365  0.948575      0.463497
# 95                  2976          1381  0.959694      0.464046
# 96                  3007          1391  0.966644      0.462587
# 97                  3038          1402  0.974288      0.461488
# 98                  3069          1421  0.987491      0.463017
# 99                  3100          1439  1.000000      0.464194
#
# [100 rows x 9 columns]

# %%
os.chdir('../output_data/')

# %%
df_val.columns
# Out:
# Index(['Symbol', 'Date', 'Series', 'Prev_Close_order5', 'High_1d_order5',
#        'Low_1d_order5', 'Last_1d_order5', 'VWAP_1d_order5', 'Volume_1d_order9',
#        'Turnover_1d_order11',
#        ...
#        'Voltality_500_log', 'RF_Prediction', 'GBM_Prediction', 'LR_Prediction',
#        'RF_full_prediction', 'GBM_full_prediction', 'GBM_pca_prediction',
#        'RF_pca_prediction', 'Ensembled_Prob', 'ensembled_prob2'],
#       dtype='object', length=228)

# %%
df_val.to_csv('validation_predicted.csv',index=False)

# %%
os.chdir('../Statistics/')

# %%
df_val.to_excel('future_predictions.xlsx',sheet_name='data',index=False)
